# %% [markdown]
# # Data Science Workflow

# %% [markdown]
# Seven stages of Data Science Workflow:
#
#
# 1. Question or problem definition.
#
# 2. Acquire training and testing data.
#
# 3. Wrangle, prepare, and cleanse data.
#
# 4. Analyze, identify patterns, and explore the data.
#
# 5. Model, predict, and solve the problem.
#
# 6. Visualize, report, and present the problem solving steps and final solution.
#
# 7. Supply or submit the results.

# %% [markdown]
# Use cases with exceptions:
#
#
# 1. Combine multiple stages into single stage.
# 2. Perform a stage earlier.
# 3. Perform a stage multiple times.
# 4. Drop a stage.

# %% [markdown]
# # Question or Problem Definition

# %% [markdown]
# The age of abalone is determined by cutting the shell through the cone, staining it, and counting the number of rings through a microscope -- a boring and time-consuming task. Other measurements, which are easier to obtain, are used to predict the age. Further information, such as weather patterns and location (hence food availability) may be required to solve the problem.
#
# Using machine learning, predict the abalone age of abalone using physical measurements. The age can either regression or classification.

# %% [markdown]
# # Workflow Goals

# %% [markdown]
# 1. Classifying.
# 2. Correlating
# 3. Converting.
# 4. Completing.
# 5. Correcting.
# 6. Creating.
# 7. Charting.

# %%
# Data analysis and wrangling
import pandas as pd

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline

# Machine learning classification
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# Machine learning regression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.xgboost import XGBRegressor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-31-94cece6606ea> in <module>
#      22 from sklearn.svm import SVR
#      23 from sklearn.tree import DecisionTreeRegressor
# ---> 24 from sklearn.xgboost import XGBRegressor
#
# ModuleNotFoundError: No module named 'sklearn.xgboost'

# %% [markdown]
# # Acquire Data

# %% [markdown]
# The data has been uploaded in our directory. Pandas Python Package will help us to load the data into desired dataframe.

# %%
df = pd.read_csv('Abalone.csv')
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# # Analyze by Describing Data

# %% [markdown]
# Pandas can help us answering the following questions.

# %%
print(df.columns.values)
# Out:
# ['Sex' 'Length' 'Diameter' 'Height' 'Whole weight' 'Shucked weight'
#  'Viscera weight' 'Shell weight' 'Rings']

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.describe(percentiles=[.1, .2, .25, .3, .4, .5, .6, .7, .75, .8, .9, .99])
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 10%       0.355000     0.265000     0.090000      0.205000        0.086500
# 20%       0.425000     0.325000     0.105000      0.366000        0.157000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 30%       0.470000     0.365000     0.120000      0.508300        0.214000
# 40%       0.510000     0.395000     0.130000      0.644900        0.274500
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 60%       0.575000     0.450000     0.150000      0.930000        0.400300
# ...

# %%
df['Sex'].describe()
# Out:
# count     4177
# unique       3
# top          M
# freq      1528
# Name: Sex, dtype: object

# %%
#Analyze by Pivoting Features¶

# %%
df[['Sex', 'Rings']].groupby('Sex', as_index=False).mean().sort_values(by='Rings', ascending=False).reset_index(drop=True)
# Out:
#   Sex      Rings
# 0   F  11.129304
# 1   M  10.705497
# 2   I   7.890462

# %%
#Analyze by Visualizing Data

# %%
sns.heatmap(df.corr(), cmap='BrBG', annot=True)

# %%
sex = {'I':0, 'M':1, 'F':2}

df['Sex'] = df['Sex'].map(sex)
df.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    1   0.455     0.365   0.095        0.5140          0.2245
# 1    1   0.350     0.265   0.090        0.2255          0.0995
# 2    2   0.530     0.420   0.135        0.6770          0.2565
# 3    1   0.440     0.365   0.125        0.5160          0.2155
# 4    0   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %%
sns.pairplot(df, hue='Sex')

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['Rings'], axis=1)
y = df.Rings

X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=0)

# %%
from sklearn.metrics import mean_absolute_error as mae

model_classify = [LogisticRegression, SVC, LinearSVC, RandomForestClassifier, KNeighborsClassifier, GaussianNB, Perceptron, SGDClassifier, DecisionTreeClassifier]
model_reg = [RandomForestRegressor, SVR, DecisionTreeRegressor, XGBRegressor]

preds_classify = []
preds_reg = []

for model in model_reg:
    m = model()
    m.fit(X_train, y_train)
    preds = m.predict(X_valid)
    preds_reg.append(preds)
    print(mae(y_valid, preds))
    
for model in model_classify:
    m = model()
    m.fit(X_train, y_train)
    preds = m.predict(X_valid)
    preds_classify.append(preds)
    print(mae(y_valid, preds))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-75bdeac1831b> in <module>
#       2
#       3 model_classify = [LogisticRegression, SVC, LinearSVC, RandomForestClassifier, KNeighborsClassifier, GaussianNB, Perceptron, SGDClassifier, DecisionTreeClassifier]
# ----> 4 model_reg = [RandomForestRegressor, SVR, DecisionTreeRegressor, XGBRegressor]
#       5
#       6 preds_classify = []
#
# NameError: name 'XGBRegressor' is not defined
